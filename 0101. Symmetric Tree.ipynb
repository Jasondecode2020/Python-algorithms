# %% [markdown]
# ## 101. Symmetric Tree

# %% [raw]
# Easy
#
# Given the root of a binary tree, check whether it is a mirror of itself (i.e., symmetric around its center).
#
# Example 1:
#
# Input: root = [1,2,2,3,4,4,3]
# Output: true

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [raw]
# Example 2:
#
# Input: root = [1,2,2,null,3,null,3]
# Output: false
#
# Constraints:
#
# The number of nodes in the tree is in the range [1, 1000].
# -100 <= Node.val <= 100
#
# Follow up: Could you solve it both recursively and iteratively?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### method 1: tree

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def isSymmetric(self, root):
        if root is None:
            return True
        return self.isMirror(root.left, root.right)
    def isMirror(self, leftRoot, rightRoot):
        if leftRoot and rightRoot:
            return leftRoot.val == rightRoot.val and self.isMirror(leftRoot.left, rightRoot.right) \
        and self.isMirror(leftRoot.right, rightRoot.left)
        return leftRoot == rightRoot

# %%
s = Solution()
p = TreeNode(1)
p.left = TreeNode(2)
p.right = TreeNode(2)
p.left.left = TreeNode(3)
p.left.right = TreeNode(4)
p.right.left = TreeNode(4)
p.right.right = TreeNode(3)
s.isSymmetric(p)
# Out:
# True
